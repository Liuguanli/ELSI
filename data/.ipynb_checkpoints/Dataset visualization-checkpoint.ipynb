# %%
import matplotlib.pyplot as plt
# from mpl_toolkits.axisartist.axislines import SubplotZero
# import matplotlib.patches as patches
import random
import math
import copy
import time
import pandas as pd

import sys

import numpy as np
# import tensorflow as tf
import csv
import os

# %%
input_data_file = "/home/research/datasets/NYC_143752359_1_2_.csv"
xs = []
ys = []
with open(input_data_file) as csvfile:
    lines = csvfile.readlines()

    for line in lines:
        row = line.strip().split(',')
        xs.append(float(row[0]))
        ys.append(float(row[1]))

# %%
xs_sp = [xs[i] for i in range(0, len(xs), 100)]
ys_sp = [ys[i] for i in range(0, len(ys), 100)]
plt.axis('off')
plt.scatter(xs_sp, ys_sp, s=1)
plt.savefig(root + "/NYC.eps", format='eps', bbox_inches='tight')

# %%
input_data_file = "/home/research/datasets/TPCH_125995823_1_2_.csv"
xs1 = []
ys1 = []
with open(input_data_file) as csvfile:
    lines = csvfile.readlines()

    for line in lines:
        row = line.strip().split(',')
        xs1.append(float(row[0]))
        ys1.append(float(row[1]))

# %%
xs1_sp = [xs1[i] for i in range(0, len(xs1), 10000)]
ys1_sp = [ys1[i] for i in range(0, len(ys1), 10000)]
plt.axis('off')
plt.scatter(xs1_sp, ys1_sp, s=1)
plt.savefig(root + "/NYC.eps", format='eps', bbox_inches='tight')

# %%
input_data_file = "/home/research/datasets/OSM_100000000_1_2_.csv"
xs2 = []
ys2 = []
with open(input_data_file) as csvfile:
    lines = csvfile.readlines()
    for line in lines:
        row = line.strip().split(',')
        xs2.append(float(row[0]))
        ys2.append(float(row[1]))
xs2_sp = [xs2[i] for i in range(0, len(xs2), 10000)]
ys2_sp = [ys2[i] for i in range(0, len(ys2), 10000)]
plt.axis('off')
plt.scatter(xs2_sp, ys2_sp, s=1)

# %%
def data_vis(input_data_file, tag):
    xs = []
    ys = []
    with open(input_data_file) as csvfile:
        lines = csvfile.readlines()

        for line in lines:
            row = line.strip().split(',')
            xs.append(float(row[0]))
            ys.append(float(row[1]))
    xs_sp = [xs[i] for i in range(0, len(xs), 100)]
    ys_sp = [ys[i] for i in range(0, len(ys), 100)]
    plt.axis('off')
    plt.scatter(xs_sp, ys_sp, s=1)
    plt.savefig(rag + ".eps", format='eps', bbox_inches='tight')

# %%
datasets = [
    "/home/research/datasets/OSM_100000000_1_2_.csv",
    "/home/research/datasets/NYC_143752359_1_2_.csv",
    "/home/research/datasets/TPCH_125995823_1_2_.csv",
    "/home/research/datasets/SA_180000000_1_2_.csv",
"/home/research/datasets/uniform_128000000_1_2_.csv",
"/home/research/datasets/skewed_128000000_4_2_.csv"]
tags = ["OSM1", "NYC", "TPCH", "OSM2", "uniform", "skewed"]
for i in range(len(datasets)):
    data_vis(datasets[i], tags[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_666618/410000840.py in <module>
#       4 tags = ["OSM2", "uniform", "skewed"]
#       5 for i in range(len(datasets)):
# ----> 6     data_vis(datasets[i], tags[i])
#
# NameError: name 'data_vis' is not defined
